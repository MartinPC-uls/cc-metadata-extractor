# %%
import pandas as pd

# %%
df = pd.read_csv('dest/CC-MAIN-20231128083443-20231128113443-00000.csv')
df
# Out:
#                                          WARC-File  \
# 0      CC-MAIN-20231128083443-20231128113443-00000
# 1      CC-MAIN-20231128083443-20231128113443-00000
# 2      CC-MAIN-20231128083443-20231128113443-00000
# 3      CC-MAIN-20231128083443-20231128113443-00000
# 4      CC-MAIN-20231128083443-20231128113443-00000
# ...                                            ...
# 36793  CC-MAIN-20231128083443-20231128113443-00000
# 36794  CC-MAIN-20231128083443-20231128113443-00000
# 36795  CC-MAIN-20231128083443-20231128113443-00000
# 36796  CC-MAIN-20231128083443-20231128113443-00000
# 36797  CC-MAIN-20231128083443-20231128113443-00000
#
#                                         WARC-Record-ID  \
# 0      <urn:uuid:60a1e8f3-68a9-437c-937c-e52edd95c91c>
# 1      <urn:uuid:6d583533-efec-4864-89ea-6c1a5eacdbb2>
# 2      <urn:uuid:121e2fb4-a2e8-432b-b909-41c6855c1365>
# 3      <urn:uuid:2f09a1f3-184b-4674-98b4-d3846ebed303>
# 4      <urn:uuid:c8df538a-b1d3-45aa-9c7b-1bbb82244a58>
# ...

# %%
df[:8]
# Out:
#                                      WARC-File  \
# 0  CC-MAIN-20231128083443-20231128113443-00000
# 1  CC-MAIN-20231128083443-20231128113443-00000
# 2  CC-MAIN-20231128083443-20231128113443-00000
# 3  CC-MAIN-20231128083443-20231128113443-00000
# 4  CC-MAIN-20231128083443-20231128113443-00000
# 5  CC-MAIN-20231128083443-20231128113443-00000
# 6  CC-MAIN-20231128083443-20231128113443-00000
# 7  CC-MAIN-20231128083443-20231128113443-00000
#
#                                     WARC-Record-ID  \
# 0  <urn:uuid:60a1e8f3-68a9-437c-937c-e52edd95c91c>
# 1  <urn:uuid:6d583533-efec-4864-89ea-6c1a5eacdbb2>
# 2  <urn:uuid:121e2fb4-a2e8-432b-b909-41c6855c1365>
# 3  <urn:uuid:2f09a1f3-184b-4674-98b4-d3846ebed303>
# 4  <urn:uuid:c8df538a-b1d3-45aa-9c7b-1bbb82244a58>
# 5  <urn:uuid:6d9b2d4f-be6a-4bec-b2bb-bfce70053a0a>
# 6  <urn:uuid:35a34d4a-50ab-4b42-bc88-db7840d624cd>
# 7  <urn:uuid:28566d2c-5665-44ff-b783-176b0d3fc4c2>
#
# ...

# %%
# Languages found in Content-Language
sorted(map(str, list(set(df['Content-Language'].to_list()))))
# Out:
# ['NL-nl',
#  'af',
#  'am',
#  'an',
#  'ar',
#  'ar-QA',
#  'ar-SA-u-nu-latn',
#  'ast',
#  'av',
#  'az',
#  'ba',
#  'be',
#  'bg',
#  'bg-BG',
#  'big5',
#  'bn',
#  'bo',
#  'broadcasts',
#  'ca',
#  'contact',
#  'cs',
#  'cs-CZ',
#  'cy',
#  'cy-GB',
#  'da',
#  'da-DK',
#  'de',
#  'de-AT',
#  'de-CH',
#  'de-DE',
#  'de-de',
#  'de-x-formal',
#  'default',
#  'el',
#  'en',
#  'en,en-ca',
#  'en,en-us',
#  'en-',
#  'en-AU',
#  'en-CA',
#  'en-EN',
#  'en-GB',
#  'en-GB-x-lvariant-MO',
#  'en-Global',
#  'en-HK',
#  'en-MY',
#  'en-NZ',
#  'en-UK',
#  'en-US',
#  'en-US,bg,en',
#  'en-US-x-lvariant-USA',
#  'en-ca',
#  'en-gb',
#  'en-nz',
#  'en-us',
#  'eo',
#  'es',
#  'es-419',
#  'es-CL',
#  'es-ES',
#  'es-MX',
#  'et',
#  'eu',
#  'fa',
#  'fi',
#  'fi-FI',
#  'fr',
#  'fr,fr-be',
#  'fr-CA',
#  'fr-FR',
#  'fr-be',
#  'fr-ca',
#  'fr-fr',
#  'ga',
#  'gl',
#  'gu',
#  'he',
#  'hi',
#  'hi-IN-u-nu-deva',
#  'hr',
#  'hu',
#  'hu-HU',
#  'id',
#  'ie',
#  'inh',
# ...

# %%
# Languages found in HTML-Language
sorted(map(str, list(set(df['HTML-Language'].to_list()))))
# Out:
# ['CS',
#  'DE',
#  'EN',
#  'EN-TH',
#  'ES',
#  'En',
#  'FR',
#  'HR',
#  'HR/hr',
#  'IT',
#  'JP',
#  'MX',
#  'NL',
#  'PL',
#  'PT',
#  'PT-br',
#  'RU',
#  'SV',
#  'TW',
#  'af-ZA',
#  'af-za',
#  'am',
#  'am-AM',
#  'ar',
#  'ar-145',
#  'ar-AE',
#  'ar-AR',
#  'ar-SA',
#  'ar-aa',
#  'ar-iq',
#  'ar-sa',
#  'as',
#  'ast',
#  'az',
#  'az-AZ',
#  'base-diocese',
#  'bcc',
#  'be',
#  'be-BY',
#  'bg',
#  'bg-BG',
#  'bg-bg',
#  'bm',
#  'bn',
#  'bo',
#  'br',
#  'bs-BA',
#  'by',
#  'ca',
#  'ca-ES',
#  'ca-es',
#  'ch',
#  'cmn-hans',
#  'cn',
#  'co',
#  'code',
#  'cs',
#  'cs-CZ',
#  'cs-cz',
#  'cs><head> <meta http-equiv=',
#  'cy',
#  'cy-GB',
#  'cz',
#  'da',
#  'da-DA',
#  'da-DK',
#  'da-dk',
#  'de',
#  'de-AT',
#  'de-CH',
#  'de-DE',
#  'de-DE-formal',
#  'de-at',
#  'de-ch',
#  'de-de',
#  'de-formal',
#  'de-us',
#  'de-x-formal',
#  'de_AT',
#  'de_DE',
#  'dir=',
#  'dz',
#  'e',
#  'el',
#  'el-GR',
#  'el-cy',
#  'el-gr',
#  'en',
#  'en,jp',
# ...
